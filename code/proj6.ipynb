# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet
from torchsummary import summary

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True (the environment provided does
# not support GPUs and we will not provide any support for GPU
# computation in this project). Please note that 
# we will evaluate your implementations only using CPU mode so even if
# you use a GPU, make sure your code runs in the CPU mode with the
# environment we provided. 
use_GPU = False
if use_GPU:
    from utils_gpu import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 0. Warm up! Training a Deep Network from Scratch

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# You do not need to code anything for this part. You will simply run the code we provided, but we want you to report the result you got. This section will also familiarize you with the steps of training a deep network from scratch.

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 1e-2  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# We will first create our datasets, by calling the create_datasets function from student_code. This function returns a separate dataset loader for each split of the dataset (training and testing/validation). Each dataloader is used to load the datasets after appling some pre-processing transforms. In Part 1, you will be asked to add a few more pre-processing transforms to the dataloaders by modifying this function.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now we will create our network model using the SimpleNet class from student_code. The implementation provided in the SimpleNet class gives you a basic network. In Part 1, you will be asked to add a few more layers to this network.

# %%
# Create the network model.
model = sc.SimpleNet(num_classes=num_classes, rgb=RGB, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 20, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Conv2d(20, 15, kernel_size=(5, 5), stride=(1, 1), bias=False)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): ReLU()
#     (7): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Conv2d(15, 10, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(8, 8), stride=(1, 1))
# )

# %% [markdown]
# Next we will create the loss function and the optimizer.

# %%
# Create the loss function.
# see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
loss_function = nn.CrossEntropyLoss()

# %%
# Create the optimizer and a learning rate scheduler
optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
# Currently a simple step scheduler.
# See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
# and how to use them
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

# %% [markdown]
# Finally we are ready to train our network! We will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# train the network!
params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# checkpoint_file: None
# do_val: True
# print_freq: 100
# experiment: part1
# val_freq: 1
# shuffle: True
# num_workers: 4
# batch_size: 50
# n_epochs: 100
# resume_optim: True
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.766, top-1 accuracy 8.000, top-5 accuracy 38.000
# train part1: loss 2.606670
# val part1: batch 0/59, loss 2.821, top-1 accuracy 4.000, top-5 accuracy 50.000
# val part1: loss 2.819745
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.313, top-1 accuracy 28.000, top-5 accuracy 68.000
# train part1: loss 2.362745
# val part1: batch 0/59, loss 2.740, top-1 accuracy 26.000, top-5 accuracy 58.000
# val part1: loss 2.243742
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.001, top-1 accuracy 36.000, top-5 accuracy 80.000
# train part1: loss 2.104323
# val part1: batch 0/59, loss 2.518, top-1 accuracy 10.000, top-5 accuracy 74.000
# val part1: loss 2.117861
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 1.725, top-1 accuracy 42.000, top-5 accuracy 88.000
# train part1: loss 1.938006
# val part1: batch 0/59, loss 2.396, top-1 accuracy 30.000, top-5 accuracy 70.000
# val part1: loss 1.881535
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 1.791, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.859233
# val part1: batch 0/59, loss 1.831, top-1 accuracy 36.000, top-5 accuracy 80.000
# val part1: loss 2.027947
# Checkpoint saved
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 1.836, top-1 accuracy 44.000, top-5 accuracy 76.000
# train part1: loss 1.783747
# val part1: batch 0/59, loss 2.421, top-1 accuracy 28.000, top-5 accuracy 66.000
# val part1: loss 1.864428
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 1.587, top-1 accuracy 46.000, top-5 accuracy 82.000
# train part1: loss 1.859626
# val part1: batch 0/59, loss 1.975, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.861958
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 1.793, top-1 accuracy 40.000, top-5 accuracy 86.000
# train part1: loss 1.748166
# val part1: batch 0/59, loss 2.102, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.787948
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 1.541, top-1 accuracy 44.000, top-5 accuracy 88.000
# train part1: loss 1.687195
# val part1: batch 0/59, loss 2.134, top-1 accuracy 32.000, top-5 accuracy 68.000
# val part1: loss 1.908590
# Checkpoint saved
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 1.744, top-1 accuracy 46.000, top-5 accuracy 88.000
# train part1: loss 1.692424
# val part1: batch 0/59, loss 2.155, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.720379
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.637, top-1 accuracy 46.000, top-5 accuracy 82.000
# train part1: loss 1.575030
# val part1: batch 0/59, loss 2.634, top-1 accuracy 16.000, top-5 accuracy 64.000
# val part1: loss 1.743065
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.754, top-1 accuracy 48.000, top-5 accuracy 76.000
# train part1: loss 1.621531
# val part1: batch 0/59, loss 2.063, top-1 accuracy 28.000, top-5 accuracy 76.000
# val part1: loss 1.904368
# Checkpoint saved
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.746, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.628944
# val part1: batch 0/59, loss 2.029, top-1 accuracy 22.000, top-5 accuracy 80.000
# val part1: loss 1.705599
# Checkpoint saved
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.709, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.567134
# val part1: batch 0/59, loss 2.353, top-1 accuracy 12.000, top-5 accuracy 70.000
# val part1: loss 1.702109
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.623, top-1 accuracy 50.000, top-5 accuracy 84.000
# train part1: loss 1.543057
# val part1: batch 0/59, loss 2.208, top-1 accuracy 20.000, top-5 accuracy 74.000
# val part1: loss 1.671576
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.675, top-1 accuracy 48.000, top-5 accuracy 84.000
# train part1: loss 1.508771
# val part1: batch 0/59, loss 2.348, top-1 accuracy 16.000, top-5 accuracy 70.000
# val part1: loss 1.665880
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.148, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.468356
# val part1: batch 0/59, loss 1.661, top-1 accuracy 40.000, top-5 accuracy 82.000
# val part1: loss 1.752854
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.332, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.439782
# val part1: batch 0/59, loss 2.002, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.621801
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.746, top-1 accuracy 32.000, top-5 accuracy 86.000
# train part1: loss 1.434246
# val part1: batch 0/59, loss 1.819, top-1 accuracy 32.000, top-5 accuracy 88.000
# val part1: loss 1.629166
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.457, top-1 accuracy 52.000, top-5 accuracy 86.000
# train part1: loss 1.382328
# val part1: batch 0/59, loss 2.151, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.776490
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.871, top-1 accuracy 32.000, top-5 accuracy 88.000
# train part1: loss 1.425156
# val part1: batch 0/59, loss 1.526, top-1 accuracy 42.000, top-5 accuracy 88.000
# val part1: loss 1.766599
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.540, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.398961
# val part1: batch 0/59, loss 2.500, top-1 accuracy 18.000, top-5 accuracy 74.000
# val part1: loss 1.758953
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.219, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.344060
# val part1: batch 0/59, loss 1.768, top-1 accuracy 38.000, top-5 accuracy 80.000
# val part1: loss 1.633435
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.328, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.432303
# val part1: batch 0/59, loss 2.140, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.623342
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.308, top-1 accuracy 66.000, top-5 accuracy 88.000
# train part1: loss 1.318183
# val part1: batch 0/59, loss 1.791, top-1 accuracy 36.000, top-5 accuracy 80.000
# val part1: loss 1.591573
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.202, top-1 accuracy 64.000, top-5 accuracy 94.000
# train part1: loss 1.382437
# val part1: batch 0/59, loss 1.804, top-1 accuracy 44.000, top-5 accuracy 78.000
# val part1: loss 1.649494
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.391, top-1 accuracy 52.000, top-5 accuracy 90.000
# train part1: loss 1.309111
# val part1: batch 0/59, loss 2.077, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.531674
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.025, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.227106
# val part1: batch 0/59, loss 1.789, top-1 accuracy 38.000, top-5 accuracy 88.000
# val part1: loss 1.537344
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.239, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.252713
# val part1: batch 0/59, loss 1.842, top-1 accuracy 44.000, top-5 accuracy 86.000
# val part1: loss 1.523442
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.062, top-1 accuracy 72.000, top-5 accuracy 92.000
# train part1: loss 1.273532
# val part1: batch 0/59, loss 2.018, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.515643
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.111, top-1 accuracy 64.000, top-5 accuracy 94.000
# train part1: loss 1.222781
# val part1: batch 0/59, loss 1.516, top-1 accuracy 54.000, top-5 accuracy 90.000
# val part1: loss 1.555842
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 0.741, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 1.183059
# val part1: batch 0/59, loss 1.996, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.582396
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.319, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.189183
# val part1: batch 0/59, loss 1.720, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.549428
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.355, top-1 accuracy 48.000, top-5 accuracy 96.000
# train part1: loss 1.189813
# val part1: batch 0/59, loss 2.116, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.683420
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.003, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 1.178824
# val part1: batch 0/59, loss 1.586, top-1 accuracy 40.000, top-5 accuracy 88.000
# val part1: loss 1.693494
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.189, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.114890
# val part1: batch 0/59, loss 1.999, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.535068
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.093, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.128760
# val part1: batch 0/59, loss 2.388, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 1.484097
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 0.784, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 1.141871
# val part1: batch 0/59, loss 2.092, top-1 accuracy 32.000, top-5 accuracy 80.000
# val part1: loss 1.662131
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.293, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.160597
# val part1: batch 0/59, loss 1.770, top-1 accuracy 34.000, top-5 accuracy 86.000
# val part1: loss 1.650297
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 1.053, top-1 accuracy 60.000, top-5 accuracy 98.000
# train part1: loss 1.101770
# val part1: batch 0/59, loss 2.639, top-1 accuracy 10.000, top-5 accuracy 62.000
# val part1: loss 1.577120
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 0.847, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 1.100907
# val part1: batch 0/59, loss 2.025, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.542916
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.231, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.105726
# val part1: batch 0/59, loss 2.521, top-1 accuracy 26.000, top-5 accuracy 66.000
# val part1: loss 1.699719
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.103, top-1 accuracy 70.000, top-5 accuracy 94.000
# train part1: loss 1.064917
# val part1: batch 0/59, loss 2.027, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.478926
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 0.736, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 1.046410
# val part1: batch 0/59, loss 1.537, top-1 accuracy 46.000, top-5 accuracy 88.000
# val part1: loss 1.509400
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 0.889, top-1 accuracy 74.000, top-5 accuracy 96.000
# train part1: loss 1.053321
# val part1: batch 0/59, loss 2.066, top-1 accuracy 24.000, top-5 accuracy 80.000
# val part1: loss 1.523476
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.806, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.010459
# val part1: batch 0/59, loss 1.365, top-1 accuracy 52.000, top-5 accuracy 90.000
# val part1: loss 1.770498
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 1.132, top-1 accuracy 60.000, top-5 accuracy 98.000
# train part1: loss 1.050338
# val part1: batch 0/59, loss 2.157, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.617229
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.708, top-1 accuracy 82.000, top-5 accuracy 96.000
# train part1: loss 1.040553
# val part1: batch 0/59, loss 1.768, top-1 accuracy 38.000, top-5 accuracy 86.000
# val part1: loss 1.545424
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.982, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.994981
# val part1: batch 0/59, loss 2.095, top-1 accuracy 30.000, top-5 accuracy 78.000
# val part1: loss 1.510449
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 1.099, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 1.039960
# val part1: batch 0/59, loss 1.677, top-1 accuracy 48.000, top-5 accuracy 86.000
# val part1: loss 1.742755
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 0.699, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 1.012576
# val part1: batch 0/59, loss 2.333, top-1 accuracy 22.000, top-5 accuracy 80.000
# val part1: loss 1.566281
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 0.801, top-1 accuracy 70.000, top-5 accuracy 94.000
# train part1: loss 0.995437
# val part1: batch 0/59, loss 2.160, top-1 accuracy 28.000, top-5 accuracy 72.000
# val part1: loss 1.660220
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.957, top-1 accuracy 72.000, top-5 accuracy 94.000
# train part1: loss 0.996501
# val part1: batch 0/59, loss 1.586, top-1 accuracy 48.000, top-5 accuracy 92.000
# val part1: loss 1.695910
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.072, top-1 accuracy 64.000, top-5 accuracy 94.000
# train part1: loss 1.026099
# val part1: batch 0/59, loss 1.727, top-1 accuracy 38.000, top-5 accuracy 90.000
# val part1: loss 1.547719
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.891, top-1 accuracy 80.000, top-5 accuracy 94.000
# train part1: loss 0.944969
# val part1: batch 0/59, loss 1.743, top-1 accuracy 38.000, top-5 accuracy 86.000
# val part1: loss 1.614955
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.674, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.930145
# val part1: batch 0/59, loss 1.696, top-1 accuracy 40.000, top-5 accuracy 90.000
# val part1: loss 1.530800
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.059, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 0.928296
# val part1: batch 0/59, loss 2.315, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.656194
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.887, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 0.943684
# val part1: batch 0/59, loss 1.489, top-1 accuracy 54.000, top-5 accuracy 84.000
# val part1: loss 1.572955
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.965, top-1 accuracy 76.000, top-5 accuracy 96.000
# train part1: loss 0.938070
# val part1: batch 0/59, loss 1.957, top-1 accuracy 34.000, top-5 accuracy 88.000
# val part1: loss 1.507222
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 1.103, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 0.945708
# val part1: batch 0/59, loss 2.259, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.579573
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.912, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 0.819448
# val part1: batch 0/59, loss 1.783, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.481127
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.581, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.820679
# val part1: batch 0/59, loss 1.838, top-1 accuracy 38.000, top-5 accuracy 88.000
# val part1: loss 1.449883
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.764, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.748924
# val part1: batch 0/59, loss 1.880, top-1 accuracy 34.000, top-5 accuracy 88.000
# val part1: loss 1.439972
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.487, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.730495
# val part1: batch 0/59, loss 1.836, top-1 accuracy 38.000, top-5 accuracy 86.000
# val part1: loss 1.454760
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.692, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.740861
# val part1: batch 0/59, loss 1.945, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.461933
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.743, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.735178
# val part1: batch 0/59, loss 1.994, top-1 accuracy 36.000, top-5 accuracy 80.000
# val part1: loss 1.466686
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.845, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 0.749997
# val part1: batch 0/59, loss 1.879, top-1 accuracy 34.000, top-5 accuracy 82.000
# val part1: loss 1.479066
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.678, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 0.716954
# val part1: batch 0/59, loss 1.975, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.466852
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.826, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 0.709768
# val part1: batch 0/59, loss 1.995, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.455809
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.720, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.700472
# val part1: batch 0/59, loss 2.001, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.478814
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.795, top-1 accuracy 80.000, top-5 accuracy 94.000
# train part1: loss 0.691748
# val part1: batch 0/59, loss 1.984, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.500759
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.596, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.710307
# val part1: batch 0/59, loss 1.917, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.477701
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.457, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.676943
# val part1: batch 0/59, loss 1.857, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.502818
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.757, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 0.701694
# val part1: batch 0/59, loss 2.058, top-1 accuracy 32.000, top-5 accuracy 76.000
# val part1: loss 1.478870
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.790, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 0.691050
# val part1: batch 0/59, loss 1.949, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.483374
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.533, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.696847
# val part1: batch 0/59, loss 1.919, top-1 accuracy 34.000, top-5 accuracy 90.000
# val part1: loss 1.498675
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.647, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 0.694974
# val part1: batch 0/59, loss 2.070, top-1 accuracy 34.000, top-5 accuracy 78.000
# val part1: loss 1.512044
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.893, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 0.698542
# val part1: batch 0/59, loss 2.037, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.490884
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.592, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.679266
# val part1: batch 0/59, loss 1.878, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.505230
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.559, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.667916
# val part1: batch 0/59, loss 2.010, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.508023
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.764, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.695579
# val part1: batch 0/59, loss 1.873, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.522660
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.529, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.671817
# val part1: batch 0/59, loss 1.942, top-1 accuracy 38.000, top-5 accuracy 86.000
# val part1: loss 1.515769
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.662, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.695228
# val part1: batch 0/59, loss 2.191, top-1 accuracy 30.000, top-5 accuracy 78.000
# val part1: loss 1.556740
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.742, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 0.670727
# val part1: batch 0/59, loss 1.897, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.521160
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.655, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.683457
# val part1: batch 0/59, loss 2.066, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.525468
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.680, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.687020
# val part1: batch 0/59, loss 1.924, top-1 accuracy 34.000, top-5 accuracy 82.000
# val part1: loss 1.539408
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.801, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.675095
# val part1: batch 0/59, loss 1.769, top-1 accuracy 38.000, top-5 accuracy 90.000
# val part1: loss 1.554542
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.628, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.667645
# val part1: batch 0/59, loss 1.949, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.516258
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.591, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.661264
# val part1: batch 0/59, loss 1.937, top-1 accuracy 34.000, top-5 accuracy 88.000
# val part1: loss 1.532964
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.863, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 0.639465
# val part1: batch 0/59, loss 1.942, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.535482
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.635, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 0.646864
# val part1: batch 0/59, loss 2.126, top-1 accuracy 34.000, top-5 accuracy 80.000
# val part1: loss 1.549568
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.750, top-1 accuracy 78.000, top-5 accuracy 96.000
# train part1: loss 0.638483
# val part1: batch 0/59, loss 1.909, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.553142
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.487, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.643098
# val part1: batch 0/59, loss 1.976, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.543832
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.703, top-1 accuracy 84.000, top-5 accuracy 96.000
# train part1: loss 0.649829
# val part1: batch 0/59, loss 2.000, top-1 accuracy 38.000, top-5 accuracy 80.000
# val part1: loss 1.553222
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.537, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.634810
# val part1: batch 0/59, loss 1.986, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.529741
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.579, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.662182
# val part1: batch 0/59, loss 2.273, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.577841
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.798, top-1 accuracy 76.000, top-5 accuracy 96.000
# train part1: loss 0.645972
# val part1: batch 0/59, loss 1.954, top-1 accuracy 36.000, top-5 accuracy 82.000
# val part1: loss 1.566056
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.507, top-1 accuracy 88.000, top-5 accuracy 98.000
# train part1: loss 0.651620
# val part1: batch 0/59, loss 1.913, top-1 accuracy 34.000, top-5 accuracy 86.000
# val part1: loss 1.548065
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.280, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.625239
# val part1: batch 0/59, loss 2.049, top-1 accuracy 36.000, top-5 accuracy 78.000
# val part1: loss 1.564872
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.734, top-1 accuracy 76.000, top-5 accuracy 96.000
# train part1: loss 0.627992
# val part1: batch 0/59, loss 2.068, top-1 accuracy 34.000, top-5 accuracy 80.000
# val part1: loss 1.551631
# Checkpoint saved
# Best top-1 Accuracy = 56.516

# %%
from torchsummary import summary
summary(model, (1, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 20, 56, 56]           1,620
#          MaxPool2d-2           [-1, 20, 27, 27]               0
#               ReLU-3           [-1, 20, 27, 27]               0
#        BatchNorm2d-4           [-1, 20, 27, 27]              40
#             Conv2d-5           [-1, 15, 23, 23]           7,500
#          MaxPool2d-6           [-1, 15, 11, 11]               0
#               ReLU-7           [-1, 15, 11, 11]               0
#        BatchNorm2d-8           [-1, 15, 11, 11]              30
#             Conv2d-9             [-1, 10, 8, 8]           2,400
#         LeakyReLU-10             [-1, 10, 8, 8]               0
#       BatchNorm2d-11             [-1, 10, 8, 8]              20
#           Dropout-12             [-1, 10, 8, 8]               0
#            Conv2d-13             [-1, 15, 1, 1]           9,615
# ================================================================
# Total params: 21,225
# Trainable params: 21,225
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.93
# Params size (MB): 0.08
# Estimated Total Size (MB): 1.03
# ----------------------------------------------------------------

# %% [markdown]
# Expect this code to take around 5 minutes on CPU or 3 minutes on GPU. Now you are ready to actually modify the functions we used to train our model. Before you move on, make sure to record the accuracy of your network from Part 0, and report it in your write up.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Now you will modify the create_datasets function from student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will also add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should achieve an accuracy of at least **50%**. Make sure your network passes this threshold--it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=RGB, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# summary(model, (1, 64, 64))
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 20, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Conv2d(20, 15, kernel_size=(5, 5), stride=(1, 1), bias=False)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): ReLU()
#     (7): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Conv2d(15, 10, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(8, 8), stride=(1, 1))
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
print(s)
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is ', out.size())
# Out:
# torch.Size([1, 64, 64])
# Network output size is  torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since we will not be using the notebook you submit to evaluate.

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part1
# val_freq: 1
# experiment: part1
# num_workers: 4
# checkpoint_file: None
# print_freq: 100
# do_val: True
# shuffle: True
# resume_optim: True
# batch_size: 50
# n_epochs: 100
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.690, top-1 accuracy 18.000, top-5 accuracy 40.000
# train part1: loss 2.617591
# val part1: batch 0/59, loss 3.639, top-1 accuracy 4.000, top-5 accuracy 52.000
# val part1: loss 2.592904
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.161, top-1 accuracy 32.000, top-5 accuracy 74.000
# train part1: loss 2.370665
# val part1: batch 0/59, loss 2.686, top-1 accuracy 22.000, top-5 accuracy 60.000
# val part1: loss 2.264099
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.186, top-1 accuracy 32.000, top-5 accuracy 72.000
# train part1: loss 2.111187
# val part1: batch 0/59, loss 2.477, top-1 accuracy 26.000, top-5 accuracy 64.000
# val part1: loss 2.163903
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.100, top-1 accuracy 24.000, top-5 accuracy 76.000
# train part1: loss 2.012376
# val part1: batch 0/59, loss 2.376, top-1 accuracy 20.000, top-5 accuracy 68.000
# val part1: loss 1.927348
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 1.778, top-1 accuracy 42.000, top-5 accuracy 80.000
# train part1: loss 1.836012
# val part1: batch 0/59, loss 2.316, top-1 accuracy 12.000, top-5 accuracy 66.000
# val part1: loss 1.810001
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 1.500, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.789363
# val part1: batch 0/59, loss 2.140, top-1 accuracy 14.000, top-5 accuracy 72.000
# val part1: loss 1.796112
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 1.737, top-1 accuracy 40.000, top-5 accuracy 88.000
# train part1: loss 1.792164
# val part1: batch 0/59, loss 2.451, top-1 accuracy 12.000, top-5 accuracy 70.000
# val part1: loss 1.869063
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 1.687, top-1 accuracy 42.000, top-5 accuracy 80.000
# train part1: loss 1.692813
# val part1: batch 0/59, loss 2.213, top-1 accuracy 22.000, top-5 accuracy 74.000
# val part1: loss 1.808842
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 1.580, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.657134
# val part1: batch 0/59, loss 1.860, top-1 accuracy 40.000, top-5 accuracy 80.000
# val part1: loss 1.779455
# Checkpoint saved
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 1.484, top-1 accuracy 54.000, top-5 accuracy 88.000
# train part1: loss 1.649939
# val part1: batch 0/59, loss 2.399, top-1 accuracy 14.000, top-5 accuracy 78.000
# val part1: loss 1.949816
# Checkpoint saved
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.700, top-1 accuracy 50.000, top-5 accuracy 82.000
# train part1: loss 1.573972
# val part1: batch 0/59, loss 1.895, top-1 accuracy 34.000, top-5 accuracy 78.000
# val part1: loss 1.724239
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.197, top-1 accuracy 72.000, top-5 accuracy 90.000
# train part1: loss 1.530829
# val part1: batch 0/59, loss 2.696, top-1 accuracy 14.000, top-5 accuracy 66.000
# val part1: loss 1.763328
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.545, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.506153
# val part1: batch 0/59, loss 2.137, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.592795
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.138, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.441034
# val part1: batch 0/59, loss 1.871, top-1 accuracy 40.000, top-5 accuracy 80.000
# val part1: loss 1.681395
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.514, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.451297
# val part1: batch 0/59, loss 1.965, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.606378
# Checkpoint saved
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.451, top-1 accuracy 58.000, top-5 accuracy 88.000
# train part1: loss 1.413026
# val part1: batch 0/59, loss 1.937, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.725094
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.248, top-1 accuracy 58.000, top-5 accuracy 90.000
# train part1: loss 1.398899
# val part1: batch 0/59, loss 2.038, top-1 accuracy 24.000, top-5 accuracy 78.000
# val part1: loss 1.613255
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.323, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.359530
# val part1: batch 0/59, loss 2.566, top-1 accuracy 18.000, top-5 accuracy 66.000
# val part1: loss 1.715550
# Checkpoint saved
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.300, top-1 accuracy 62.000, top-5 accuracy 90.000
# train part1: loss 1.325783
# val part1: batch 0/59, loss 1.757, top-1 accuracy 44.000, top-5 accuracy 82.000
# val part1: loss 1.565571
# Checkpoint saved
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.193, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.290812
# val part1: batch 0/59, loss 2.167, top-1 accuracy 30.000, top-5 accuracy 72.000
# val part1: loss 1.629006
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.174, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.290097
# val part1: batch 0/59, loss 1.956, top-1 accuracy 28.000, top-5 accuracy 88.000
# val part1: loss 1.485018
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.137, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.254772
# val part1: batch 0/59, loss 2.598, top-1 accuracy 18.000, top-5 accuracy 78.000
# val part1: loss 1.752369
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.296, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.296998
# val part1: batch 0/59, loss 1.981, top-1 accuracy 34.000, top-5 accuracy 82.000
# val part1: loss 1.467351
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 0.780, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 1.213272
# val part1: batch 0/59, loss 1.991, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.474464
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 0.958, top-1 accuracy 64.000, top-5 accuracy 100.000
# train part1: loss 1.189802
# val part1: batch 0/59, loss 2.175, top-1 accuracy 20.000, top-5 accuracy 86.000
# val part1: loss 1.722086
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.155, top-1 accuracy 64.000, top-5 accuracy 90.000
# train part1: loss 1.199657
# val part1: batch 0/59, loss 2.101, top-1 accuracy 34.000, top-5 accuracy 78.000
# val part1: loss 1.514600
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 0.862, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 1.223927
# val part1: batch 0/59, loss 2.826, top-1 accuracy 16.000, top-5 accuracy 70.000
# val part1: loss 1.617260
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.233, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 1.155115
# val part1: batch 0/59, loss 2.314, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.598195
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.027, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.144358
# val part1: batch 0/59, loss 2.155, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.540107
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 0.879, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.146863
# val part1: batch 0/59, loss 2.308, top-1 accuracy 28.000, top-5 accuracy 78.000
# val part1: loss 1.502763
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.261, top-1 accuracy 54.000, top-5 accuracy 96.000
# train part1: loss 1.114481
# val part1: batch 0/59, loss 2.938, top-1 accuracy 18.000, top-5 accuracy 68.000
# val part1: loss 1.683573
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.112, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 1.095515
# val part1: batch 0/59, loss 2.258, top-1 accuracy 30.000, top-5 accuracy 76.000
# val part1: loss 1.494590
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 0.961, top-1 accuracy 76.000, top-5 accuracy 96.000
# train part1: loss 1.133202
# val part1: batch 0/59, loss 2.380, top-1 accuracy 32.000, top-5 accuracy 74.000
# val part1: loss 1.601961
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 0.884, top-1 accuracy 64.000, top-5 accuracy 100.000
# train part1: loss 1.110684
# val part1: batch 0/59, loss 1.766, top-1 accuracy 38.000, top-5 accuracy 90.000
# val part1: loss 1.677622
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.388, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part1: loss 1.107912
# val part1: batch 0/59, loss 2.058, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.428044
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.051, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 1.036693
# val part1: batch 0/59, loss 2.314, top-1 accuracy 24.000, top-5 accuracy 74.000
# val part1: loss 1.547773
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 0.989, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 1.114377
# val part1: batch 0/59, loss 2.298, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.551372
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.275, top-1 accuracy 66.000, top-5 accuracy 86.000
# train part1: loss 1.098630
# val part1: batch 0/59, loss 1.996, top-1 accuracy 40.000, top-5 accuracy 84.000
# val part1: loss 1.507405
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.019, top-1 accuracy 62.000, top-5 accuracy 96.000
# train part1: loss 1.006459
# val part1: batch 0/59, loss 2.282, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.476056
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 0.973, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 1.026220
# val part1: batch 0/59, loss 2.063, top-1 accuracy 42.000, top-5 accuracy 82.000
# val part1: loss 1.512518
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 1.193, top-1 accuracy 56.000, top-5 accuracy 94.000
# train part1: loss 1.000477
# val part1: batch 0/59, loss 2.013, top-1 accuracy 36.000, top-5 accuracy 78.000
# val part1: loss 1.495726
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 0.791, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.944000
# val part1: batch 0/59, loss 2.001, top-1 accuracy 38.000, top-5 accuracy 86.000
# val part1: loss 1.554744
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.161, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.012961
# val part1: batch 0/59, loss 2.323, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.606222
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.208, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 0.978774
# val part1: batch 0/59, loss 2.390, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.533216
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.109, top-1 accuracy 58.000, top-5 accuracy 96.000
# train part1: loss 0.929324
# val part1: batch 0/59, loss 2.180, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.544392
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.928, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 0.990026
# val part1: batch 0/59, loss 2.372, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.467876
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 0.900, top-1 accuracy 66.000, top-5 accuracy 100.000
# train part1: loss 0.929563
# val part1: batch 0/59, loss 2.562, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.642395
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.826, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 1.079978
# val part1: batch 0/59, loss 2.415, top-1 accuracy 24.000, top-5 accuracy 72.000
# val part1: loss 1.813796
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.965, top-1 accuracy 68.000, top-5 accuracy 98.000
# train part1: loss 1.016068
# val part1: batch 0/59, loss 1.984, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.492363
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 0.626, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.960924
# val part1: batch 0/59, loss 2.140, top-1 accuracy 32.000, top-5 accuracy 82.000
# val part1: loss 1.561936
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 1.050, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 0.959483
# val part1: batch 0/59, loss 2.161, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.524707
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 0.775, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.894590
# val part1: batch 0/59, loss 2.069, top-1 accuracy 34.000, top-5 accuracy 90.000
# val part1: loss 1.694025
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.893, top-1 accuracy 70.000, top-5 accuracy 96.000
# train part1: loss 0.862922
# val part1: batch 0/59, loss 2.303, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.606988
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.335, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 0.906972
# val part1: batch 0/59, loss 2.056, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.540932
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.699, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.860515
# val part1: batch 0/59, loss 2.462, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.721906
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.825, top-1 accuracy 78.000, top-5 accuracy 96.000
# train part1: loss 0.866963
# val part1: batch 0/59, loss 2.310, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.571523
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.094, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 0.891637
# val part1: batch 0/59, loss 2.161, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.647244
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.597, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.922682
# val part1: batch 0/59, loss 2.183, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.598351
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.990, top-1 accuracy 78.000, top-5 accuracy 92.000
# train part1: loss 0.786501
# val part1: batch 0/59, loss 2.654, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.541789
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 0.756, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.833455
# val part1: batch 0/59, loss 2.708, top-1 accuracy 22.000, top-5 accuracy 76.000
# val part1: loss 1.571992
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.777, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 0.757156
# val part1: batch 0/59, loss 2.377, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.481459
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.858, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.719781
# val part1: batch 0/59, loss 2.303, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.457319
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.577, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.693419
# val part1: batch 0/59, loss 2.301, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.456096
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.780, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 0.699305
# val part1: batch 0/59, loss 2.295, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.464000
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.657, top-1 accuracy 80.000, top-5 accuracy 96.000
# train part1: loss 0.711228
# val part1: batch 0/59, loss 2.210, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.464444
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.501, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.676730
# val part1: batch 0/59, loss 2.316, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.451889
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.644, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.663670
# val part1: batch 0/59, loss 2.412, top-1 accuracy 24.000, top-5 accuracy 80.000
# val part1: loss 1.464238
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.712, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.652890
# val part1: batch 0/59, loss 2.422, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.458489
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.559, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.644582
# val part1: batch 0/59, loss 2.343, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.486641
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.829, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.657768
# val part1: batch 0/59, loss 2.260, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.471744
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.533, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.645403
# val part1: batch 0/59, loss 2.372, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.488691
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.762, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.659325
# val part1: batch 0/59, loss 2.394, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.484905
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.788, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.635942
# val part1: batch 0/59, loss 2.352, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.483937
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.697, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 0.663835
# val part1: batch 0/59, loss 2.241, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.478826
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.684, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 0.633911
# val part1: batch 0/59, loss 2.391, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.496855
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.642, top-1 accuracy 80.000, top-5 accuracy 96.000
# train part1: loss 0.657247
# val part1: batch 0/59, loss 2.412, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.500945
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.556, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.630290
# val part1: batch 0/59, loss 2.484, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.496840
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.541, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.645700
# val part1: batch 0/59, loss 2.383, top-1 accuracy 32.000, top-5 accuracy 84.000
# val part1: loss 1.493242
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.741, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.625421
# val part1: batch 0/59, loss 2.387, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.503379
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.609, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.624533
# val part1: batch 0/59, loss 2.527, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.505616
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.804, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 0.627477
# val part1: batch 0/59, loss 2.507, top-1 accuracy 26.000, top-5 accuracy 80.000
# val part1: loss 1.502291
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.650, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.644908
# val part1: batch 0/59, loss 2.464, top-1 accuracy 30.000, top-5 accuracy 80.000
# val part1: loss 1.504356
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.640, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 0.640724
# val part1: batch 0/59, loss 2.355, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.520380
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.655, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.669504
# val part1: batch 0/59, loss 2.415, top-1 accuracy 30.000, top-5 accuracy 84.000
# val part1: loss 1.509879
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.630, top-1 accuracy 74.000, top-5 accuracy 98.000
# train part1: loss 0.622070
# val part1: batch 0/59, loss 2.395, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.496907
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.487, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.624447
# val part1: batch 0/59, loss 2.407, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.504187
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.506, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.608432
# val part1: batch 0/59, loss 2.370, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.532520
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.541, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.601487
# val part1: batch 0/59, loss 2.457, top-1 accuracy 28.000, top-5 accuracy 80.000
# val part1: loss 1.527478
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.564, top-1 accuracy 70.000, top-5 accuracy 98.000
# train part1: loss 0.616504
# val part1: batch 0/59, loss 2.423, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.525437
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.658, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.597866
# val part1: batch 0/59, loss 2.390, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.545494
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.452, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.593498
# val part1: batch 0/59, loss 2.404, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.524353
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.658, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.608064
# val part1: batch 0/59, loss 2.408, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.528863
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.664, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.593318
# val part1: batch 0/59, loss 2.436, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.529473
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.731, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 0.617937
# val part1: batch 0/59, loss 2.456, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.541022
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.447, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.582432
# val part1: batch 0/59, loss 2.484, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.551101
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.472, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part1: loss 0.606767
# val part1: batch 0/59, loss 2.469, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.536432
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.406, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.593557
# val part1: batch 0/59, loss 2.585, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.565360
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.744, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 0.627319
# val part1: batch 0/59, loss 2.523, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.559188
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.467, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.588050
# val part1: batch 0/59, loss 2.664, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.545268
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.531, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.589348
# val part1: batch 0/59, loss 2.477, top-1 accuracy 26.000, top-5 accuracy 82.000
# val part1: loss 1.550599
# Checkpoint saved
# Best top-1 Accuracy = 56.616

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model and fine tune it for our purposes. This is the goal of Part 2--you will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45611589 0.45611589 0.45611589]
# std =
# [0.24786406 0.24786406 0.24786406]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45549639 0.45549639 0.45549639]
# std =
# [0.24698076 0.24698076 0.24698076]

# %% [markdown]
# Following block loads a pretrained AlexNet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify create_part2_model from student code in order to fine-tune AlexNet. As you can see in the docs (https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py) and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
summary(model, (3, 224, 224))
# Out:
# Linear(in_features=4096, out_features=1000, bias=True)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=128, bias=False)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=15, bias=False)
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
#           Dropout-14                 [-1, 9216]               0
#            Linear-15                 [-1, 4096]      37,752,832
#              ReLU-16                 [-1, 4096]               0
#           Dropout-17                 [-1, 4096]               0
#            Linear-18                 [-1, 4096]      16,781,312
#              ReLU-19                 [-1, 4096]               0
#            Linear-20                  [-1, 128]         524,288
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 15]           1,920
# ================================================================
# Total params: 57,530,048
# Trainable params: 57,530,048
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.30
# Params size (MB): 219.46
# Estimated Total Size (MB): 228.34
# ----------------------------------------------------------------

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part2
# checkpoint_file: None
# do_val: True
# print_freq: 100
# experiment: part2
# val_freq: 1
# shuffle: True
# num_workers: 4
# batch_size: 10
# n_epochs: 4
# resume_optim: True
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 2.829, top-1 accuracy 0.000, top-5 accuracy 0.000
# train part2: batch 100/149, loss 0.923, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: loss 1.205987
# val part2: batch 0/298, loss 0.686, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.468, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.619, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.521730
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 0.572, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.483, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.493208
# val part2: batch 0/298, loss 0.767, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.626, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.373, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.433814
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.149, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.338, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.395725
# val part2: batch 0/298, loss 1.676, top-1 accuracy 20.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.491, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.480, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.418352
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.159, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.667, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: loss 0.335555
# val part2: batch 0/298, loss 0.709, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.394, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.436, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.405110
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# Best top-1 Accuracy = 85.695

# %% [markdown]
# Expect this code to take around 10 minutes on CPU or 30 seconds on GPU. You should hit 80% accuracy.

# %% [markdown]
# # Extra Credit: Human Sketch
